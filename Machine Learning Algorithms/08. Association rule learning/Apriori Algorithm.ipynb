# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Market_Basket_Optimisation.csv", header = None)

# %%
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
new_data=[]
for i in range(7501):
    new_data.append([str(data.values[i,j]) for j in range(20)])

# %%
new_data
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
from apyori import apriori
rules=apriori(new_data,min_support=0.003,min_confidence=0.2,min_lift=2,min_length=2)

# %%
results=list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]),
#  RelationRecord(items=frozenset({'bacon', 'spaghetti'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.36923076923076925, lift=2.1206738131699847)]),
#  RelationRecord(items=frozenset({'black tea', 'milk'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'milk'}), confidence=0.29906542056074764, lift=2.3079112341833006)]),
# ...

# %%
lift=[]
association=[]
for i in range(len(results)):
    lift.append(results[:len(results)][i][2][0][3])
    association.append(list(results[:len(results)][i][0]))

# %%
conclusion=pd.DataFrame([association,lift]).T
conclusion.columns=["association","lift"]

# %%
conclusion.sort_values("lift", ascending=False)
# Out:
#                                            association     lift
# 327      [whole wheat pasta, olive oil, mineral water]  6.11586
# 635  [whole wheat pasta, olive oil, mineral water, ...  6.11586
# 678  [nan, frozen vegetables, soup, milk, mineral w...  5.48441
# 534     [soup, mineral water, milk, frozen vegetables]  5.48441
# 200                        [honey, fromage blanc, nan]  5.16427
# ..                                                 ...      ...
# 190                  [ground beef, milk, french fries]  2.00347
# 424          [chocolate, nan, mineral water, escalope]  2.00266
# 120               [chocolate, mineral water, escalope]  2.00266
# 389                   [spaghetti, pancakes, cake, nan]  2.00054
# 87                         [pancakes, cake, spaghetti]  2.00054
#
# [689 rows x 2 columns]
