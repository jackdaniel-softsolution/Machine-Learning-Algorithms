# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
df.plot()

# %%
df["species"].value_counts() #the data set is balanced
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.plot(kind="scatter",x="sepal_length",y="sepal_width")
plt.show()

# %% [markdown]
# # scatrer plot

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df,hue="species",height=5).map(plt.scatter,"petal_length","petal_width").add_legend()
plt.show()

# %%
#when we use petal length and petal_width then all setosa flowers are separated from other two flowers
#but the versicolor and verginica are join together

# %% [markdown]
# # pair plots

# %%
#sns.set_style("whitegrid")
sns.pairplot(df,hue="species",size=3)
plt.show()

# %%
#the petal_length and petal_width are the most important feature

# %% [markdown]
# # one D scatter plot

# %%
setosa=df.loc[df["species"]=="setosa"] 
versicolor=df.loc[df["species"]=="versicolor"] 
virginica=df.loc[df["species"]=="virginica"] 

plt.plot(setosa["petal_length"],np.zeros_like(setosa["petal_length"]))
plt.plot(versicolor["petal_length"],np.zeros_like(versicolor["petal_length"]))
plt.plot(virginica["petal_length"],np.zeros_like(virginica["petal_length"]))

plt.show()

# %% [markdown]
# # Histogram and PDF

# %%
sns.FacetGrid(df,hue="species",size=6).map(sns.distplot,"petal_length").add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#setosa flower have petal length <2

# %%
sns.FacetGrid(df,hue="species",size=6).map(sns.distplot,"petal_width").add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.FacetGrid(df,hue="species",size=6).map(sns.distplot,"sepal_length").add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.FacetGrid(df,hue="species",size=6).map(sns.distplot,"sepal_width").add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#based on the above analysis
       
            #  pl>pw>>>sl>>>sw
#that means petal_length is slightly better than petal_width
#petal_width is significantly better than sepal_length
#sepal_length is also significantly better than sepal_width

# %% [markdown]
# # CDF

# %%
counts,bin_edges=np.histogram(setosa["petal_length"],bins=10,density=True)

# %%
print(counts)
print(bin_edges)
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
pdf=counts/sum(counts)

# %%
print(pdf)
print(bin_edges)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# %%
#setosa

counts,bin_edges=np.histogram(setosa["petal_length"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
#versicolr
counts,bin_edges=np.histogram(versicolor["petal_length"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
#verginica
counts,bin_edges=np.histogram(virginica["petal_length"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# %% [markdown]
# # Mean,Std

# %%
print(np.mean(setosa["petal_length"]))
print(np.mean(versicolor["petal_length"]))
print(np.mean(virginica["petal_length"]))
# Out:
# 1.464
# 4.26
# 5.5520000000000005

# %%
#the mean tells the all setosa flower average petal_length is 1.46
print(np.std(setosa["petal_length"]))
print(np.std(versicolor["petal_length"]))
print(np.std(virginica["petal_length"]))
# Out:
# 0.17176728442867112
# 0.4651881339845203
# 0.546347874526844

# %% [markdown]
# # Median

# %%
print(np.median(setosa["petal_length"]))
print(np.median(versicolor["petal_length"]))
print(np.median(virginica["petal_length"]))
# Out:
# 1.5
# 4.35
# 5.55

# %% [markdown]
# # percentiles, Quantile

# %%
print(np.percentile(setosa["petal_length"],90))
print(np.percentile(versicolor["petal_length"],90))
print(np.percentile(virginica["petal_length"],90))
# Out:
# 1.7
# 4.8
# 6.3100000000000005

# %%
print(np.percentile(setosa["petal_length"],np.arange(0,100,25)))
print(np.percentile(versicolor["petal_length"],np.arange(0,100,25)))
print(np.percentile(virginica["petal_length"],np.arange(0,100,25)))
# Out:
# [1.    1.4   1.5   1.575]
# [3.   4.   4.35 4.6 ]
# [4.5   5.1   5.55  5.875]

# %% [markdown]
# # box pots

# %%
sns.boxplot(x="species",y="petal_length",data=df)
plt.show()

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x="species",y="petal_length",data=df)
plt.show()
